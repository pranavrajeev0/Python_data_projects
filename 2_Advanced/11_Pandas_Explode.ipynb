# %%
# importing libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_exploded = df.explode('job_skills')

df_exploded
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_exploded.value_counts('job_skills').head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
skill_count = df_exploded.groupby(['job_title_short','job_skills']).size()

# %%
df_skill_count = skill_count.reset_index(name='skill_count').sort_values(by='skill_count',ascending=False)

df_skill_count
# Out:
#        job_title_short  job_skills  skill_count
# 1066    Data Scientist      python       113711
# 865      Data Engineer         sql       113130
# 830      Data Engineer      python       108022
# 625       Data Analyst         sql        92428
# 1101    Data Scientist         sql        78982
# ...                ...         ...          ...
# 462       Data Analyst     chainer            1
# 432     Cloud Engineer       wrike            1
# 410     Cloud Engineer      theano            1
# 24    Business Analyst     chainer            1
# 29    Business Analyst  codecommit            1
#
# [2256 rows x 3 columns]

# %%
job_title = 'Data Analyst'
top_skills = 10

df_skill_count_final = df_skill_count[df_skill_count['job_title_short'] == job_title].head(top_skills)

df_skill_count_final.plot(kind='barh', y='skill_count', x='job_skills')
plt.gca().invert_yaxis()
plt.title(f'Top {top_skills} for the job {job_title}')
plt.ylabel('')
plt.xlabel('Job Posting Count')
plt.legend().set_visible(False)
plt.show()
